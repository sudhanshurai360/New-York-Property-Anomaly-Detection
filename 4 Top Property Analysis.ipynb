# %%
from datetime import datetime
start_time = datetime.now()

# Load libraries
# %pip install openpyxl
# %pip install xlwt

from sklearn.neural_network import MLPRegressor
import pandas as pd
import numpy as np
import scipy.stats as sps
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
# %matplotlib inline

print('LOAD DURATION:',datetime.now() - start_time) # about 3 seconds
# Out:
# LOAD DURATION: 0:00:01.117677

# %% [markdown]
# ## Heatmap Analysis

# %%
# The heatmaps are good for seeing which variables are driving the high scores
data_base_vars = data_zs_top_n.iloc[:,0:17].abs()
data_heatmap = data_base_vars.head(20)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n_abs = data_zs_top_n.abs()
data_heatmap = data_zs_top_n.abs().head(20)
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
top_records_df = pd.DataFrame(top_records)

# %%
# Use this cell if you want to write out the top n record numbers
top_records_df.to_csv('top_n_record_numbers.csv', index=False)

# %%
# # Use this cell if you want to compare to a previous top n record numbers.
# # You can run a baseline model, see which records score the highest, then change some of the algorithm parameters
# # to see what % of these top scoring records change. The top records are insensitive to changes in the 
# # powers for the Minkowski distance measures for the two scores

# top_records_previous = pd.read_csv('top_n_record_numbers.csv')
# print(top_records_df.head())
# print(top_records_previous.head())
# num_common = len(pd.merge(top_records_df,top_records_previous, on='RECORD'))
# percent_common = 100*num_common/ntop
# percent_common

# %%
print('Duration: ', datetime.now() - start_time)
# Out:
# Duration:  0:01:30.288441

# %%
data_zs_top_n
# Out:
#               r1         r2         r3         r4          r5          r6  \
# RECORD
# 996722 -0.401017  -0.522013  -0.489278  -0.149547   -0.060280   -0.056308
# 917942  0.748372  67.425821  46.162233  41.781054  884.036490  625.448873
# 691986 -0.401020  -0.522087  -0.489316  -0.149533   -0.060276   -0.056306
# 718883 -0.401019  -0.522087  -0.489316  -0.062929   -0.035784   -0.052594
# 649717 -0.401020  -0.522084  -0.489314  -0.149544   -0.060276   -0.056306
# ...          ...        ...        ...        ...         ...         ...
# 284202 -0.400562  -0.521634  -0.489238  -0.149522   -0.060272   -0.056307
# 284210 -0.400562  -0.521634  -0.489238  -0.149522   -0.060272   -0.056307
# 284180 -0.400562  -0.521634  -0.489238  -0.149522   -0.060272   -0.056307
# 284189 -0.400562  -0.521634  -0.489238  -0.149522   -0.060272   -0.056307
# 284205 -0.400562  -0.521634  -0.489238  -0.149522   -0.060272   -0.056307
#
#                r7          r8          r9       r1inv  ...     r9_boro  \
# RECORD                                                 ...
# 996722  -0.131617   -0.054132   -0.058326   82.652966  ...   -0.063585
# 917942  37.343529  934.683271  888.115885   -0.019207  ...  878.644110
# 691986  -0.131612   -0.054130   -0.058325  440.955064  ...   -0.063584
# 718883  -0.131614   -0.054131   -0.058326  209.479461  ...   -0.063585
# 649717  -0.131616   -0.054130   -0.058325  375.294667  ...   -0.063584
# ...           ...         ...         ...         ...  ...         ...
# 284202  -0.131078   -0.053907   -0.058273    0.686071  ...   -0.063517
# 284210  -0.131078   -0.053907   -0.058273    0.686071  ...   -0.063517
# 284180  -0.131078   -0.053907   -0.058273    0.686071  ...   -0.063517
# 284189  -0.131078   -0.053907   -0.058273    0.686071  ...   -0.063517
# 284205  -0.131078   -0.053907   -0.058273    0.686071  ...   -0.063517
#
#         r1inv_boro  r2inv_boro  r3inv_boro  r4inv_boro  r5inv_boro  \
# RECORD
# 996722   42.937024    1.482004    0.994522  946.488587  174.972244
# 917942   -0.017069   -0.022383   -0.020923   -0.019640   -0.051044
# 691986  623.760734  734.299300  515.504434   17.512301   37.928851
# 718883  296.328155  435.907872  776.557831   -0.016821   -0.043399
# 649717  530.881168  133.490644   93.710958   82.048427   37.928851
# ...            ...         ...         ...         ...         ...
# 284202    0.973640    1.135203    1.253050    6.153289   14.631679
# 284210    0.973640    1.135203    1.253050    6.153289   14.631679
# 284180    0.973640    1.135203    1.253050    6.153289   14.631679
# 284189    0.973640    1.135203    1.253050    6.153289   14.631679
# 284205    0.973640    1.135203    1.253050    6.153289   14.631679
#
#         r6inv_boro  r7inv_boro  r8inv_boro  r9inv_boro
# RECORD
# 996722  103.273998  944.698744  159.761215  157.237747
# 917942   -0.034001   -0.015956   -0.040393   -0.046285
# 691986   19.530223   51.928600   79.717483  105.463825
# 718883   -0.024008   74.017774  142.004459  476.769696
# 649717   19.530223  243.139595   79.717483  105.463825
# ...            ...         ...         ...         ...
# 284202    9.286954    0.479192    0.772396    1.765224
# 284210    9.286954    0.479192    0.772396    1.765224
# 284180    9.286954    0.479192    0.772396    1.765224
# 284189    9.286954    0.479192    0.772396    1.765224
# 284205    9.286954    0.479192    0.772396    1.765224
#
# [1000 rows x 90 columns]

# %%
data_heatmap = data_zs_top_n.abs()[0:150]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[20:80]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[40:60]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[60:80]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[0:150]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[150:300]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[340:390]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[450:600]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[600:750]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[750:900]
plt.rcParams['figure.figsize'] = (30,20)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs()[900:1050]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %% [markdown]
# #### Group 1

# %%
data_heatmap = data_zs_top_n.abs().loc[[718883,7034,7039,7036,7041]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n.abs().loc[[718883,7034,7039,7036,7041]]
# Out:
#               r1        r2        r3        r4        r5        r6        r7  \
# RECORD
# 718883  0.401019  0.522087  0.489316  0.062929  0.035784  0.052594  0.131614
# 7034    0.401018  0.522086  0.489316  0.149545  0.060280  0.056308  0.131614
# 7039    0.401018  0.522086  0.489316  0.149545  0.060280  0.056308  0.131614
# 7036    0.401018  0.522086  0.489316  0.149545  0.060280  0.056308  0.131614
# 7041    0.401018  0.522086  0.489316  0.149545  0.060280  0.056308  0.131614
#
#               r8        r9       r1inv  ...   r9_boro  r1inv_boro  r2inv_boro  \
# RECORD                                  ...
# 718883  0.054131  0.058326  209.479461  ...  0.063585  296.328155  435.907872
# 7034    0.054131  0.058326  139.646478  ...  0.063585   59.342426   78.490958
# 7039    0.054131  0.058326  139.646478  ...  0.063585   59.342426   78.490958
# 7036    0.054131  0.058326  139.646478  ...  0.063585   59.342426   78.490958
# 7041    0.054131  0.058326  139.646478  ...  0.063585   59.342426   78.490958
#
#         r3inv_boro  r4inv_boro  r5inv_boro  r6inv_boro  r7inv_boro  \
# RECORD
# 718883  776.557831    0.016821    0.043399    0.024008   74.017774
# 7034     46.402330   44.081936  109.304763   44.181253   45.805818
# 7039     46.402330   44.081936  109.304763   44.181253   45.805818
# 7036     46.402330   44.081936  109.304763   44.181253   45.805818
# 7041     46.402330   44.081936  109.304763   44.181253   45.805818
#
#         r8inv_boro  r9inv_boro
# RECORD
# 718883  142.004459  476.769696
# 7034    119.850219   85.765770
# 7039    119.850219   85.765770
# 7036    119.850219   85.765770
# 7041    119.850219   85.765770
#
# [5 rows x 90 columns]

# %%
NY_data_top_n.loc[[718883,7034,7039,7036,7041]].transpose()
# Out:
# RECORD                  718883                7034                  7039    \
# BBLE                4051251107            1000531146            1000531151
# BORO                         4                     1                     1
# BLOCK                     5125                    53                    53
# LOT                       1107                  1146                  1151
# EASEMENT                   NaN                   NaN                   NaN
# OWNER          GARDEN VIEW LTD        HSIA, JONATHAN        LAMBERT, PETER
# BLDGCL                      R4                    R4                    R4
# TAXCLASS                     2                     2                     2
# LTFRONT                      0                     0                     0
# LTDEPTH                      0                     0                     0
# EXT                        NaN                   NaN                   NaN
# STORIES                   14.0                  13.0                  13.0
# FULLVAL                   12.0                  18.0                  18.0
# AVLAND                     0.0                   2.0                   2.0
# AVTOT                     10.0                  10.0                  10.0
# EXLAND                     0.0                   0.0                   0.0
# EXTOT                      2.0                   0.0                   0.0
# EXCD1                   5113.0                   NaN                   NaN
# STADDR       43-18 MAIN STREET  120 GREENWICH STREET  120 GREENWICH STREET
# ZIP                    11355.0               10006.0               10006.0
# EXMPTCL                    NaN                   NaN                   NaN
# BLDFRONT                     0                     0                     0
# BLDDEPTH                     0                     0                     0
# AVLAND2                    NaN                   NaN                   NaN
# AVTOT2                     NaN                   NaN                   NaN
# EXLAND2                    NaN                   NaN                   NaN
# EXTOT2                     NaN                   NaN                   NaN
# EXCD2                      NaN                   NaN                   NaN
# PERIOD                   FINAL                 FINAL                 FINAL
# YEAR                   2010/11               2010/11               2010/11
# VALTYPE                  AC-TR                 AC-TR                 AC-TR
# score1 rank          1046822.0             1046803.0             1046803.0
# score2 rank          1046821.0             1046815.0             1046815.0
# final                1046821.5             1046809.0             1046809.0
#
# RECORD                     7036                  7041
# BBLE                   1000531148            1000531153
# BORO                            1                     1
# BLOCK                          53                    53
# LOT                          1148                  1153
# EASEMENT                      NaN                   NaN
# OWNER             LECH, JOHN PAUL                   NaN
# BLDGCL                         R4                    R4
# TAXCLASS                        2                     2
# LTFRONT                         0                     0
# LTDEPTH                         0                     0
# EXT                           NaN                   NaN
# STORIES                      13.0                  13.0
# FULLVAL                      18.0                  18.0
# AVLAND                        2.0                   2.0
# AVTOT                        10.0                  10.0
# EXLAND                        0.0                   0.0
# EXTOT                         0.0                   0.0
# EXCD1                         NaN                   NaN
# STADDR       120 GREENWICH STREET  120 GREENWICH STREET
# ZIP                       10006.0               10006.0
# EXMPTCL                       NaN                   NaN
# BLDFRONT                        0                     0
# BLDDEPTH                        0                     0
# AVLAND2                       NaN                   NaN
# AVTOT2                        NaN                   NaN
# EXLAND2                       NaN                   NaN
# EXTOT2                        NaN                   NaN
# EXCD2                         NaN                   NaN
# PERIOD                      FINAL                 FINAL
# YEAR                      2010/11               2010/11
# VALTYPE                     AC-TR                 AC-TR
# score1 rank             1046803.0             1046803.0
# score2 rank             1046815.0             1046815.0
# final                   1046809.0             1046809.0

# %%
NY_data_top_n.loc[[7034]].transpose()
# Out:
# RECORD                       7034
# BBLE                   1000531146
# BORO                            1
# BLOCK                          53
# LOT                          1146
# EASEMENT                      NaN
# OWNER              HSIA, JONATHAN
# BLDGCL                         R4
# TAXCLASS                        2
# LTFRONT                         0
# LTDEPTH                         0
# EXT                           NaN
# STORIES                      13.0
# FULLVAL                      18.0
# AVLAND                        2.0
# AVTOT                        10.0
# EXLAND                        0.0
# EXTOT                         0.0
# EXCD1                         NaN
# STADDR       120 GREENWICH STREET
# ZIP                       10006.0
# EXMPTCL                       NaN
# BLDFRONT                        0
# BLDDEPTH                        0
# AVLAND2                       NaN
# AVTOT2                        NaN
# EXLAND2                       NaN
# EXTOT2                        NaN
# EXCD2                         NaN
# PERIOD                      FINAL
# YEAR                      2010/11
# VALTYPE                     AC-TR
# score1 rank             1046803.0
# score2 rank             1046815.0
# final                   1046809.0

# %% [markdown]
# #### Group 2

# %%
data_heatmap = data_zs_top_n.abs().loc[[12076,330292,638993,973912,665157]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n.abs().loc[[12076,330292,638993,973912,665157]]
# Out:
#               r1          r2          r3        r4          r5          r6  \
# RECORD
# 12076   0.040495  101.089390  208.803343  1.356764  123.583567  262.380577
# 330292  0.342125   65.418311  135.330393  0.050919   79.991185  169.854752
# 638993  0.344737   75.034416  155.137016  0.036817   89.169363  189.335644
# 973912  0.400461  124.789002  128.564467  0.147740  144.091801  152.926732
# 665157  0.324760  102.743983  212.211365  0.041969   92.434828  196.266669
#
#               r7         r8          r9     r1inv  ...     r9_boro  \
# RECORD                                             ...
# 12076   0.387384  50.342778  143.600959  0.018756  ...  137.081482
# 330292  0.062385  32.650795   93.168946  0.013997  ...  119.260937
# 638993  0.065455  37.420122  106.764187  0.013743  ...  105.620370
# 973912  0.130959  62.097229   88.524686  0.557970  ...  105.474796
# 665157  0.041972  51.163417  145.940239  0.015248  ...  144.378869
#
#         r1inv_boro  r2inv_boro  r3inv_boro  r4inv_boro  r5inv_boro  \
# RECORD
# 12076     0.017156    0.022389    0.020926    0.019588    0.051044
# 330292    0.009753    0.022383    0.020925    0.018872    0.051043
# 638993    0.009339    0.022384    0.020925    0.018333    0.051042
# 973912    0.282566    0.022390    0.020926    0.042756    0.051043
# 665157    0.011468    0.022385    0.020925    0.018368    0.051042
#
#         r6inv_boro  r7inv_boro  r8inv_boro  r9inv_boro
# RECORD
# 12076     0.034001    0.015666    0.040390    0.046285
# 330292    0.034001    0.012109    0.040388    0.046284
# 638993    0.034001    0.012203    0.040389    0.046284
# 973912    0.034001    0.042692    0.040392    0.046285
# 665157    0.034001    0.013188    0.040390    0.046285
#
# [5 rows x 90 columns]

# %%
NY_data_top_n.loc[[12076,330292,638993,973912,665157]].transpose()
# Out:
# RECORD                      12076                  330292  \
# BBLE                    1001790001             3019190050
# BORO                             1                      3
# BLOCK                          179                   1919
# LOT                              1                     50
# EASEMENT                       NaN                    NaN
# OWNER        15 WORTH STREET PROPE        PRATT INSTITUTE
# BLDGCL                          G6                     Z9
# TAXCLASS                         4                      4
# LTFRONT                         74                     60
# LTDEPTH                        150                    540
# EXT                            NaN                    NaN
# STORIES                        1.0                    1.0
# FULLVAL                  2610000.0              1016250.0
# AVLAND                   1170000.0               454500.0
# AVTOT                    1174500.0               457313.0
# EXLAND                         0.0               454500.0
# EXTOT                          0.0               457313.0
# EXCD1                          NaN                 1601.0
# STADDR           170 WEST BROADWAY  189 WILLOUGHBY AVENUE
# ZIP                        10013.0                11205.0
# EXMPTCL                        NaN                     X7
# BLDFRONT                         5                      3
# BLDDEPTH                         5                      5
# AVLAND2                   936900.0               406980.0
# AVTOT2                    941400.0               409490.0
# EXLAND2                        NaN               406980.0
# EXTOT2                         NaN               409490.0
# EXCD2                          NaN                    NaN
# PERIOD                       FINAL                  FINAL
# YEAR                       2010/11                2010/11
# VALTYPE                      AC-TR                  AC-TR
# score1 rank              1046816.0              1046784.0
# score2 rank              1046603.0              1046616.0
# final                    1046709.5              1046700.0
#
# RECORD                      638993               973912  \
# BBLE                    4020770098           5014000001
# BORO                             4                    5
# BLOCK                         2077                 1400
# LOT                             98                    1
# EASEMENT                       NaN                  NaN
# OWNER        ALEXANDER'S OF REGOPA   THE PORT OFNY & NJ
# BLDGCL                          G7                   Y7
# TAXCLASS                         4                    4
# LTFRONT                        379                 2800
# LTDEPTH                        205                 3700
# EXT                            NaN                  NaN
# STORIES                        1.0                  2.0
# FULLVAL                  2328900.0            3090000.0
# AVLAND                   1013220.0            1309500.0
# AVTOT                    1048005.0            1390500.0
# EXLAND                         0.0            1309500.0
# EXTOT                          0.0            1390500.0
# EXCD1                          NaN               6120.0
# STADDR        HORACE HARDING EXPWY  3668 WESTERN AVENUE
# ZIP                            NaN              10303.0
# EXMPTCL                        NaN                  NaN
# BLDFRONT                         6                    2
# BLDDEPTH                         5                   12
# AVLAND2                  1273644.0            1197000.0
# AVTOT2                   1299006.0            1278000.0
# EXLAND2                        NaN            1197000.0
# EXTOT2                         NaN            1278000.0
# EXCD2                          NaN                  NaN
# PERIOD                       FINAL                FINAL
# YEAR                       2010/11              2010/11
# VALTYPE                      AC-TR                AC-TR
# score1 rank              1046786.0            1046792.0
# score2 rank              1046604.0            1046595.0
# final                    1046695.0            1046693.5
#
# RECORD                          665157
# BBLE                        4030710001
# BORO                                 4
# BLOCK                             3071
# LOT                                  1
# EASEMENT                           NaN
# OWNER                ST JOHNS CEMETERY
# BLDGCL                              Z8
# TAXCLASS                             4
# LTFRONT                            981
# LTDEPTH                           2663
# EXT                                NaN
# STORIES                            1.0
# FULLVAL                    106100000.0
# AVLAND                      35010000.0
# AVTOT                       47745000.0
# EXLAND                      35010000.0
# EXTOT                       47745000.0
# EXCD1                           1700.0
# STADDR       80-01 METROPOLITAN AVENUE
# ZIP                            11379.0
# EXMPTCL                             X5
# BLDFRONT                            40
# BLDDEPTH                            25
# AVLAND2                     31410000.0
# AVTOT2                      44145000.0
# EXLAND2                     31410000.0
# EXTOT2                      44145000.0
# EXCD2                              NaN
# PERIOD                           FINAL
# YEAR                           2010/11
# VALTYPE                          AC-TR
# score1 rank                  1046791.0
# score2 rank                  1046567.0
# final                        1046679.0

# %% [markdown]
# - This looks like government properties

# %% [markdown]
# #### Group 3

# %%
data_heatmap = data_zs_top_n.abs().loc[[584874,584887,584880,584885,584897,584892,584863,584891,584890]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n.abs().loc[[584874,584887,584880,584885,584897,584892,584863,584891,584890]].transpose()
# Out:
# RECORD          584874      584887      584880      584885      584897  \
# r1            0.400953    0.400953    0.400953    0.400953    0.400953
# r2            0.522034    0.522034    0.522034    0.522034    0.522034
# r3            0.489305    0.489305    0.489305    0.489305    0.489305
# r4            0.149541    0.149541    0.149541    0.149541    0.149541
# r5            0.060279    0.060279    0.060279    0.060279    0.060279
# ...                ...         ...         ...         ...         ...
# r5inv_boro  112.682829  112.682829  112.682829  112.682829  112.682829
# r6inv_boro  105.220353  105.220353  105.220353  105.220353  105.220353
# r7inv_boro    3.121060    3.121060    3.121060    3.121060    3.121060
# r8inv_boro    5.978457    5.978457    5.978457    5.978457    5.978457
# r9inv_boro   14.385191   14.385191   14.385191   14.385191   14.385191
#
# RECORD          584892      584863      584891      584890
# r1            0.400953    0.400953    0.400953    0.400953
# r2            0.522034    0.522034    0.522034    0.522034
# r3            0.489305    0.489305    0.489305    0.489305
# r4            0.149541    0.149541    0.149541    0.149541
# r5            0.060279    0.060279    0.060279    0.060279
# ...                ...         ...         ...         ...
# r5inv_boro  112.682829  112.682829  112.682829  112.682829
# r6inv_boro  105.220353  105.220353  105.220353  105.220353
# r7inv_boro    3.121060    3.121060    3.121060    3.121060
# r8inv_boro    5.978457    5.978457    5.978457    5.978457
# r9inv_boro   14.385191   14.385191   14.385191   14.385191
#
# [90 rows x 9 columns]

# %%
NY_data_top_n.loc[[584874,584887,584880,584885,584897,584892,584863,584891,584890]].transpose()
# Out:
# RECORD                584874             584887           584880  \
# BBLE              4004151113         4004151126       4004151119
# BORO                       4                  4                4
# BLOCK                    415                415              415
# LOT                     1113               1126             1119
# EASEMENT                 NaN                NaN              NaN
# OWNER         KIM, YOUNG JAE  HAYASHI, HIROYUKI  SEEMAN, WILLIAM
# BLDGCL                    R4                 R4               R4
# TAXCLASS                   2                  2                2
# LTFRONT                    0                  0                0
# LTDEPTH                    0                  0                0
# EXT                      NaN                NaN              NaN
# STORIES                 10.0               10.0             10.0
# FULLVAL                525.0              525.0            525.0
# AVLAND                   6.0                6.0              6.0
# AVTOT                  236.0              236.0            236.0
# EXLAND                   0.0                0.0              0.0
# EXTOT                  229.0              229.0            229.0
# EXCD1                 5113.0             5113.0           5113.0
# STADDR       41-26 27 STREET    41-26 27 STREET  41-26 27 STREET
# ZIP                  11101.0            11101.0          11101.0
# EXMPTCL                  NaN                NaN              NaN
# BLDFRONT                   0                  0                0
# BLDDEPTH                   0                  0                0
# AVLAND2                  6.0                6.0              6.0
# AVTOT2                 221.0              221.0            221.0
# EXLAND2                  NaN                NaN              NaN
# EXTOT2                 214.0              214.0            214.0
# EXCD2                    NaN                NaN              NaN
# PERIOD                 FINAL              FINAL            FINAL
# YEAR                 2010/11            2010/11          2010/11
# VALTYPE                AC-TR              AC-TR            AC-TR
# score1 rank        1046500.0          1046500.0        1046500.0
# score2 rank        1046762.0          1046762.0        1046762.0
# final              1046631.0          1046631.0        1046631.0
#
# RECORD                    584885           584897           584892  \
# BBLE                  4004151124       4004151136       4004151131
# BORO                           4                4                4
# BLOCK                        415              415              415
# LOT                         1124             1136             1131
# EASEMENT                     NaN              NaN              NaN
# OWNER        HARGETT, KRISTEN  N  BEHAN, MARY ANN              NaN
# BLDGCL                        R4               R4               R4
# TAXCLASS                       2                2                2
# LTFRONT                        0                0                0
# LTDEPTH                        0                0                0
# EXT                          NaN              NaN              NaN
# STORIES                     10.0             10.0             10.0
# FULLVAL                    525.0            525.0            525.0
# AVLAND                       6.0              6.0              6.0
# AVTOT                      236.0            236.0            236.0
# EXLAND                       0.0              0.0              0.0
# EXTOT                      229.0            229.0            229.0
# EXCD1                     5113.0           5113.0           5113.0
# STADDR           41-26 27 STREET  41-26 27 STREET  41-26 27 STREET
# ZIP                      11101.0          11101.0          11101.0
# EXMPTCL                      NaN              NaN              NaN
# BLDFRONT                       0                0                0
# BLDDEPTH                       0                0                0
# AVLAND2                      6.0              6.0              6.0
# AVTOT2                     221.0            221.0            221.0
# EXLAND2                      NaN              NaN              NaN
# EXTOT2                     214.0            214.0            214.0
# EXCD2                        NaN              NaN              NaN
# PERIOD                     FINAL            FINAL            FINAL
# YEAR                     2010/11          2010/11          2010/11
# VALTYPE                    AC-TR            AC-TR            AC-TR
# score1 rank            1046500.0        1046500.0        1046500.0
# score2 rank            1046762.0        1046762.0        1046762.0
# final                  1046631.0        1046631.0        1046631.0
#
# RECORD                  584863              584891           584890
# BBLE                4004151102          4004151130       4004151129
# BORO                         4                   4                4
# BLOCK                      415                 415              415
# LOT                       1102                1130             1129
# EASEMENT                   NaN                 NaN              NaN
# OWNER        CHERN, JIA SHUENN  CONSTANTIN, IULIAN              NaN
# BLDGCL                      R4                  R4               R4
# TAXCLASS                     2                   2                2
# LTFRONT                      0                   0                0
# LTDEPTH                      0                   0                0
# EXT                        NaN                 NaN              NaN
# STORIES                   10.0                10.0             10.0
# FULLVAL                  525.0               525.0            525.0
# AVLAND                     6.0                 6.0              6.0
# AVTOT                    236.0               236.0            236.0
# EXLAND                     0.0                 0.0              0.0
# EXTOT                    229.0               229.0            229.0
# EXCD1                   5113.0              5113.0           5113.0
# STADDR         41-26 27 STREET     41-26 27 STREET  41-26 27 STREET
# ZIP                    11101.0             11101.0          11101.0
# EXMPTCL                    NaN                 NaN              NaN
# BLDFRONT                     0                   0                0
# BLDDEPTH                     0                   0                0
# AVLAND2                    6.0                 6.0              6.0
# AVTOT2                   221.0               221.0            221.0
# EXLAND2                    NaN                 NaN              NaN
# EXTOT2                   214.0               214.0            214.0
# EXCD2                      NaN                 NaN              NaN
# PERIOD                   FINAL               FINAL            FINAL
# YEAR                   2010/11             2010/11          2010/11
# VALTYPE                  AC-TR               AC-TR            AC-TR
# score1 rank          1046500.0           1046500.0        1046500.0
# score2 rank          1046762.0           1046762.0        1046762.0
# final                1046631.0           1046631.0        1046631.0

# %% [markdown]
# #### Group 4

# %%
data_heatmap = data_zs_top_n.abs().loc[[970506,970490,970502,970498]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n.abs().loc[[970506,970490,970502,970498]].transpose()
# Out:
# RECORD         970506     970490     970502     970498
# r1          39.648298  39.648298  39.648298  39.648298
# r2           0.018365   0.018365   0.018365   0.018365
# r3           0.301263   0.301263   0.301263   0.301263
# r4          48.767985  48.767985  48.767985  48.767985
# r5           0.159162   0.159162   0.159162   0.159162
# ...               ...        ...        ...        ...
# r5inv_boro   0.050399   0.050399   0.050399   0.050399
# r6inv_boro   0.033476   0.033476   0.033476   0.033476
# r7inv_boro   0.015962   0.015962   0.015962   0.015962
# r8inv_boro   0.040191   0.040191   0.040191   0.040191
# r9inv_boro   0.046010   0.046010   0.046010   0.046010
#
# [90 rows x 4 columns]

# %%
NY_data_top_n.loc[[970506,970490,970502,970498]].transpose()
# Out:
# RECORD              970506         970490         970502         970498
# BBLE           5011860147E    5011860139E    5011860145E    5011860143E
# BORO                     5              5              5              5
# BLOCK                 1186           1186           1186           1186
# LOT                    147            139            145            143
# EASEMENT                 E              E              E              E
# OWNER                  NaN            NaN            NaN            NaN
# BLDGCL                  Z7             Z7             Z7             Z7
# TAXCLASS                 4              4              4              4
# LTFRONT                 13             13             13             13
# LTDEPTH                 10             10             10             10
# EXT                    NaN            NaN            NaN            NaN
# STORIES                NaN            NaN            NaN            NaN
# FULLVAL                0.0            0.0            0.0            0.0
# AVLAND                 0.0            0.0            0.0            0.0
# AVTOT                  0.0            0.0            0.0            0.0
# EXLAND                 0.0            0.0            0.0            0.0
# EXTOT                  0.0            0.0            0.0            0.0
# EXCD1                  NaN            NaN            NaN            NaN
# STADDR       MARINERS LANE  MARINERS LANE  MARINERS LANE  MARINERS LANE
# ZIP                    NaN            NaN            NaN            NaN
# EXMPTCL                NaN            NaN            NaN            NaN
# BLDFRONT                 0              0              0              0
# BLDDEPTH                 0              0              0              0
# AVLAND2                NaN            NaN            NaN            NaN
# AVTOT2                 NaN            NaN            NaN            NaN
# EXLAND2                NaN            NaN            NaN            NaN
# EXTOT2                 NaN            NaN            NaN            NaN
# EXCD2                  NaN            NaN            NaN            NaN
# PERIOD               FINAL          FINAL          FINAL          FINAL
# YEAR               2010/11        2010/11        2010/11        2010/11
# VALTYPE              AC-TR          AC-TR          AC-TR          AC-TR
# score1 rank      1046636.0      1046636.0      1046636.0      1046636.0
# score2 rank      1045930.0      1045930.0      1045930.0      1045930.0
# final            1046283.0      1046283.0      1046283.0      1046283.0

# %% [markdown]
# #### Group 5

# %%
data_heatmap = data_zs_top_n.abs().loc[[678704,678703,678702,678701,678702,678705,678699,678700]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
NY_data_top_n.loc[[678704,678703,678702,678701,678702,678705,678699,678700]].transpose()
# Out:
# RECORD                    678704               678703               678702  \
# BBLE                  4034941117           4034941116           4034941115
# BORO                           4                    4                    4
# BLOCK                       3494                 3494                 3494
# LOT                         1117                 1116                 1115
# EASEMENT                     NaN                  NaN                  NaN
# OWNER        OLCHANOWSKI, LESZEK      DEL VALLE, LINA      BARDHI, SHYQYRI
# BLDGCL                        R5                   R5                   R5
# TAXCLASS                       4                    4                    4
# LTFRONT                       60                   60                   60
# LTDEPTH                      125                  125                  125
# EXT                          NaN                  NaN                  NaN
# STORIES                      3.0                  3.0                  3.0
# FULLVAL                    143.0                143.0                143.0
# AVLAND                      64.0                 64.0                 64.0
# AVTOT                       64.0                 64.0                 64.0
# EXLAND                       0.0                  0.0                  0.0
# EXTOT                        0.0                  0.0                  0.0
# EXCD1                        NaN                  NaN                  NaN
# STADDR       63-15 FOREST AVENUE  63-15 FOREST AVENUE  63-15 FOREST AVENUE
# ZIP                      11385.0              11385.0              11385.0
# EXMPTCL                      NaN                  NaN                  NaN
# BLDFRONT                       0                    0                    0
# BLDDEPTH                       0                    0                    0
# AVLAND2                      NaN                  NaN                  NaN
# AVTOT2                       NaN                  NaN                  NaN
# EXLAND2                      NaN                  NaN                  NaN
# EXTOT2                       NaN                  NaN                  NaN
# EXCD2                        NaN                  NaN                  NaN
# PERIOD                     FINAL                FINAL                FINAL
# YEAR                     2010/11              2010/11              2010/11
# VALTYPE                    AC-TR                AC-TR                AC-TR
# score1 rank            1046221.0            1046221.0            1046221.0
# score2 rank            1046545.0            1046545.0            1046545.0
# final                  1046383.0            1046383.0            1046383.0
#
# RECORD                    678701               678702               678705  \
# BBLE                  4034941114           4034941115           4034941118
# BORO                           4                    4                    4
# BLOCK                       3494                 3494                 3494
# LOT                         1114                 1115                 1118
# EASEMENT                     NaN                  NaN                  NaN
# OWNER                        NaN      BARDHI, SHYQYRI            LE, SON T
# BLDGCL                        R5                   R5                   R5
# TAXCLASS                       4                    4                    4
# LTFRONT                       60                   60                   60
# LTDEPTH                      125                  125                  125
# EXT                          NaN                  NaN                  NaN
# STORIES                      3.0                  3.0                  3.0
# FULLVAL                    143.0                143.0                143.0
# AVLAND                      64.0                 64.0                 64.0
# AVTOT                       64.0                 64.0                 64.0
# EXLAND                       0.0                  0.0                  0.0
# EXTOT                        0.0                  0.0                  0.0
# EXCD1                        NaN                  NaN                  NaN
# STADDR       63-15 FOREST AVENUE  63-15 FOREST AVENUE  63-15 FOREST AVENUE
# ZIP                      11385.0              11385.0              11385.0
# EXMPTCL                      NaN                  NaN                  NaN
# BLDFRONT                       0                    0                    0
# BLDDEPTH                       0                    0                    0
# AVLAND2                      NaN                  NaN                  NaN
# AVTOT2                       NaN                  NaN                  NaN
# EXLAND2                      NaN                  NaN                  NaN
# EXTOT2                       NaN                  NaN                  NaN
# EXCD2                        NaN                  NaN                  NaN
# PERIOD                     FINAL                FINAL                FINAL
# YEAR                     2010/11              2010/11              2010/11
# VALTYPE                    AC-TR                AC-TR                AC-TR
# score1 rank            1046221.0            1046221.0            1046221.0
# score2 rank            1046545.0            1046545.0            1046545.0
# final                  1046383.0            1046383.0            1046383.0
#
# RECORD                    678699               678700
# BBLE                  4034941112           4034941113
# BORO                           4                    4
# BLOCK                       3494                 3494
# LOT                         1112                 1113
# EASEMENT                     NaN                  NaN
# OWNER               LARCO, LOUIS                  NaN
# BLDGCL                        R5                   R5
# TAXCLASS                       4                    4
# LTFRONT                       60                   60
# LTDEPTH                      125                  125
# EXT                          NaN                  NaN
# STORIES                      3.0                  3.0
# FULLVAL                    143.0                143.0
# AVLAND                      64.0                 64.0
# AVTOT                       64.0                 64.0
# EXLAND                       0.0                  0.0
# EXTOT                        0.0                  0.0
# EXCD1                        NaN                  NaN
# STADDR       63-15 FOREST AVENUE  63-15 FOREST AVENUE
# ZIP                      11385.0              11385.0
# EXMPTCL                      NaN                  NaN
# BLDFRONT                       0                    0
# BLDDEPTH                       0                    0
# AVLAND2                      NaN                  NaN
# AVTOT2                       NaN                  NaN
# EXLAND2                      NaN                  NaN
# EXTOT2                       NaN                  NaN
# EXCD2                        NaN                  NaN
# PERIOD                     FINAL                FINAL
# YEAR                     2010/11              2010/11
# VALTYPE                    AC-TR                AC-TR
# score1 rank            1046221.0            1046221.0
# score2 rank            1046545.0            1046545.0
# final                  1046383.0            1046383.0

# %%
NY_data_top_n.groupby('ZIP')['FULLVAL'].mean()[11385]
# Out:
# 3935547.888888889

# %%
NY_data_top_n.groupby('ZIP')['AVLAND'].mean()[11385]
# Out:
# 1610899.7777777778

# %%
data_zs_top_n.abs().loc[[678704,678703,678702,678701,678702,678705,678699,678700]].transpose()
# Out:
# RECORD         678704     678703     678702     678701     678702     678705  \
# r1           0.400985   0.400985   0.400985   0.400985   0.400985   0.400985
# r2           0.522062   0.522062   0.522062   0.522062   0.522062   0.522062
# r3           0.489298   0.489298   0.489298   0.489298   0.489298   0.489298
# r4           0.149425   0.149425   0.149425   0.149425   0.149425   0.149425
# r5           0.060249   0.060249   0.060249   0.060249   0.060249   0.060249
# ...               ...        ...        ...        ...        ...        ...
# r5inv_boro   5.883314   5.883314   5.883314   5.883314   5.883314   5.883314
# r6inv_boro   1.628189   1.628189   1.628189   1.628189   1.628189   1.628189
# r7inv_boro   5.927882   5.927882   5.927882   5.927882   5.927882   5.927882
# r8inv_boro  12.421775  12.421775  12.421775  12.421775  12.421775  12.421775
# r9inv_boro   8.917927   8.917927   8.917927   8.917927   8.917927   8.917927
#
# RECORD         678699     678700
# r1           0.400985   0.400985
# r2           0.522062   0.522062
# r3           0.489298   0.489298
# r4           0.149425   0.149425
# r5           0.060249   0.060249
# ...               ...        ...
# r5inv_boro   5.883314   5.883314
# r6inv_boro   1.628189   1.628189
# r7inv_boro   5.927882   5.927882
# r8inv_boro  12.421775  12.421775
# r9inv_boro   8.917927   8.917927
#
# [90 rows x 8 columns]

# %%
data_heatmap = data_zs_top_n.abs()[240:260]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_zs_top_n.abs().loc[[255529],['r1inv','r4inv','r5inv','r6inv']].transpose()
# Out:
# RECORD     255529
# r1inv    1.215734
# r4inv   13.884301
# r5inv   39.428559
# r6inv   92.408949

# %%
NY_data_top_n.loc[[14979]].transpose()
#NY_data_top_n[NY_data_top_n['RECORD']==255529]
# Out:
# RECORD                  14979
# BBLE               1002280030
# BORO                        1
# BLOCK                     228
# LOT                        30
# EASEMENT                  NaN
# OWNER        ENJAY ASSOCIATES
# BLDGCL                     G6
# TAXCLASS                    4
# LTFRONT                   114
# LTDEPTH                    80
# EXT                       NaN
# STORIES                   1.0
# FULLVAL             2680000.0
# AVLAND              1201500.0
# AVTOT               1206000.0
# EXLAND                    0.0
# EXTOT                     0.0
# EXCD1                     NaN
# STADDR        69 GRAND STREET
# ZIP                   10013.0
# EXMPTCL                   NaN
# BLDFRONT                    8
# BLDDEPTH                    6
# AVLAND2             1281800.0
# AVTOT2              1287400.0
# EXLAND2                   NaN
# EXTOT2                    NaN
# EXCD2                     NaN
# PERIOD                  FINAL
# YEAR                  2010/11
# VALTYPE                 AC-TR
# score1 rank         1046781.0
# score2 rank         1046272.0
# final               1046526.5

# %%
NY_data_top_n[NY_data_top_n['ZIP']==11201].groupby('ZIP')['AVLAND'].median()
# Out:
# ZIP
# 11201.0    6.0
# Name: AVLAND, dtype: float64

# %%
NY_data_top_n[NY_data_top_n['ZIP']==11201]['FULLVAL'].median()
# Out:
# 1428.0

# %%
data_heatmap = data_zs_top_n.abs().loc[[111420]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
NY_data_top_n.loc[[111420]].transpose()
# Out:
# RECORD                      111420
# BBLE                    1015101092
# BORO                             1
# BLOCK                         1510
# LOT                           1092
# EASEMENT                       NaN
# OWNER        BOXWOOD FLTD PARNTERS
# BLDGCL                          R4
# TAXCLASS                         2
# LTFRONT                         75
# LTDEPTH                         93
# EXT                            NaN
# STORIES                       31.0
# FULLVAL                   296508.0
# AVLAND                     22896.0
# AVTOT                     133429.0
# EXLAND                         0.0
# EXTOT                          0.0
# EXCD1                          NaN
# STADDR               1438 3 AVENUE
# ZIP                        10028.0
# EXMPTCL                        NaN
# BLDFRONT                      7575
# BLDDEPTH                      9393
# AVLAND2                    22896.0
# AVTOT2                    146183.0
# EXLAND2                        NaN
# EXTOT2                         NaN
# EXCD2                          NaN
# PERIOD                       FINAL
# YEAR                       2010/11
# VALTYPE                      AC-TR
# score1 rank              1046793.0
# score2 rank              1046719.0
# final                    1046756.0

# %%
NY_data_top_n[NY_data_top_n['BLDFRONT']>NY_data_top_n['LTFRONT']]
# Out:
#                BBLE  BORO  BLOCK   LOT EASEMENT                  OWNER BLDGCL  \
# RECORD
# 956520   5006590012     5    659    12      NaN      TROMPETA RIZALINA     A1
# 658933   4029060054     4   2906    54      NaN        WAN CHIU CHEUNG     C0
# 111420   1015101092     1   1510  1092      NaN  BOXWOOD FLTD PARNTERS     R4
# 333412   3019850059     3   1985    59      NaN         SPOONER ALSTON     C5
# 116647   1015410021     1   1541    21      NaN   MF ASSOCIATES OF NEW     D6
# 155893   2027020001     2   2702     1      NaN  ATTRACTIVE HOME, INC.     Q1
# 60469    1010330001     1   1033     1      NaN   42/9 RESIDENTIAL LLC     D6
# 85962    1012600014     1   1260    14      NaN  WEST 44TH STREET OWNE     H2
# 282644   3009470034     3    947    34      NaN  58 ST. JOHN'S PLACE P     C2
# 748183   4065170001     4   6517     1      NaN   NEW YORK STATE OWNED     W5
# 116646   1015410001     1   1541     1      NaN  YORKVILLE PLAZA ASSOC     D6
# 257485  3001990126P     3    199   126        P  PORT OF NEW YORK AUTH     Z9
# 176664   2034327503     2   3432  7503      NaN                    NaN     R0
# 53684    1009390028     1    939    28      NaN  377 EAST 33RD FEE LLC     D9
# 376750   3036310030     3   3631    30      NaN  LINROC NURSING HOMEIN     I6
#
#        TAXCLASS  LTFRONT  LTDEPTH  ...       AVTOT2     EXLAND2       EXTOT2  \
# RECORD                             ...
# 956520        1       25       91  ...          NaN         NaN          NaN
# 658933        1       25      100  ...          NaN         NaN          NaN
# 111420        2       75       93  ...     146183.0         NaN          NaN
# 333412       2B       17       85  ...          NaN         NaN          NaN
# 116647        2       25       75  ...   66960000.0         NaN          NaN
# 155893        4        4       31  ...    1237500.0    961200.0    1237500.0
# 60469         2       20       50  ...   18512999.0   1072840.0   16660839.0
# 85962         4       18      100  ...   44222500.0         NaN          NaN
# 282644       2A       20      122  ...          NaN         NaN          NaN
# 748183        4       16     1660  ...  147042000.0  29637000.0  147042000.0
# 116646        2       25      100  ...   25641000.0         NaN          NaN
# 257485        4       60      787  ...     481521.0         NaN          NaN
# 176664        2        2       48  ...          NaN         NaN          NaN
# 53684         2       25       98  ...   22824004.0         NaN          NaN
# 376750        4       25       80  ...   10674000.0    705600.0   10674000.0
#
#          EXCD2  PERIOD     YEAR  VALTYPE  score1 rank score2 rank      final
# RECORD
# 956520     NaN   FINAL  2010/11    AC-TR    1046823.0   1046798.0  1046810.5
# 658933     NaN   FINAL  2010/11    AC-TR    1046820.0   1046799.0  1046809.5
# 111420     NaN   FINAL  2010/11    AC-TR    1046793.0   1046719.0  1046756.0
# 333412  5112.0   FINAL  2010/11    AC-TR    1046719.0   1046710.0  1046714.5
# 116647     NaN   FINAL  2010/11    AC-TR    1046789.0   1046515.0  1046652.0
# 155893     NaN   FINAL  2010/11    AC-TR    1046775.0   1046491.0  1046633.0
# 60469      NaN   FINAL  2010/11    AC-TR    1046686.0   1045938.0  1046312.0
# 85962      NaN   FINAL  2010/11    AC-TR    1046683.0   1045917.0  1046300.0
# 282644     NaN   FINAL  2010/11    AC-TR    1045957.0   1046551.0  1046254.0
# 748183     NaN   FINAL  2010/11    AC-TR    1046527.0   1045911.0  1046219.0
# 116646     NaN   FINAL  2010/11    AC-TR    1046456.0   1045534.0  1045995.0
# 257485     NaN   FINAL  2010/11    AC-TR    1045669.0   1046214.0  1045941.5
# 176664     NaN   FINAL  2010/11    AC-TR    1046260.0   1045259.0  1045759.5
# 53684      NaN   FINAL  2010/11    AC-TR    1046265.0   1045061.0  1045663.0
# 376750     NaN   FINAL  2010/11    AC-TR    1046110.0   1044855.0  1045482.5
#
# [15 rows x 34 columns]

# %%
NY_data_top_n.loc[[658933]].transpose()
# Out:
# RECORD                658933
# BBLE              4029060054
# BORO                       4
# BLOCK                   2906
# LOT                       54
# EASEMENT                 NaN
# OWNER        WAN CHIU CHEUNG
# BLDGCL                    C0
# TAXCLASS                   1
# LTFRONT                   25
# LTDEPTH                  100
# EXT                      NaN
# STORIES                  3.0
# FULLVAL             776000.0
# AVLAND               26940.0
# AVTOT                46560.0
# EXLAND                1620.0
# EXTOT                 1620.0
# EXCD1                 1017.0
# STADDR       54-76 83 STREET
# ZIP                  11373.0
# EXMPTCL                  NaN
# BLDFRONT                2500
# BLDDEPTH                5600
# AVLAND2                  NaN
# AVTOT2                   NaN
# EXLAND2                  NaN
# EXTOT2                   NaN
# EXCD2                    NaN
# PERIOD                 FINAL
# YEAR                 2010/11
# VALTYPE                AC-TR
# score1 rank        1046820.0
# score2 rank        1046799.0
# final              1046809.5

# %%
data_heatmap = data_zs_top_n.abs().loc[[658933]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
data_heatmap = data_zs_top_n.abs().loc[[956520]]
plt.rcParams['figure.figsize'] = (20,10)
ax = sns.heatmap(data_heatmap, center=0, vmin=0, vmax=50, cmap='Reds')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top')
plt.xticks(rotation=90)
plt.savefig('heatmap.png')

# %%
NY_data_top_n.loc[[956520]].transpose()
# Out:
# RECORD                  956520
# BBLE                5006590012
# BORO                         5
# BLOCK                      659
# LOT                         12
# EASEMENT                   NaN
# OWNER        TROMPETA RIZALINA
# BLDGCL                      A1
# TAXCLASS                     1
# LTFRONT                     25
# LTDEPTH                     91
# EXT                          G
# STORIES                    3.0
# FULLVAL               348200.0
# AVLAND                 15600.0
# AVTOT                  20892.0
# EXLAND                  1620.0
# EXTOT                   1620.0
# EXCD1                   1017.0
# STADDR        12 ONEIDA AVENUE
# ZIP                    10301.0
# EXMPTCL                    NaN
# BLDFRONT                  1812
# BLDDEPTH                  5020
# AVLAND2                    NaN
# AVTOT2                     NaN
# EXLAND2                    NaN
# EXTOT2                     NaN
# EXCD2                      NaN
# PERIOD                   FINAL
# YEAR                   2010/11
# VALTYPE                  AC-TR
# score1 rank          1046823.0
# score2 rank          1046798.0
# final                1046810.5
