# %% [markdown]
# # Data Quality Analysis

# %%
import numpy as n
import pandas as p
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=p.read_csv('NY property data.csv')
data.head().transpose()
# Out:
#                               0                      1                      2  \
# RECORD                        1                      2                      3
# BBLE                 1000010101             1000010201             1000020001
# BORO                          1                      1                      1
# BLOCK                         1                      1                      2
# LOT                         101                    201                      1
# EASEMENT                    NaN                    NaN                    NaN
# OWNER     U S GOVT LAND & BLDGS  U S GOVT LAND & BLDGS  DEPT OF GENERAL SERVI
# BLDGCL                       P7                     Z9                     Y7
# TAXCLASS                      4                      4                      4
# LTFRONT                     500                     27                    709
# LTDEPTH                    1046                      0                    564
# ...

# %%
data.shape
# Out:
# (1070994, 32)

# %%
data.loc[:,['BBLE','BORO','BLOCK','LOT']].sample(20)
# Out:
#                BBLE  BORO  BLOCK   LOT
# 108478   1014730042     1   1473    42
# 507539   3071320047     3   7132    47
# 175126   2033790006     2   3379     6
# 783415   4085520006     4   8552     6
# 707190   4047830029     4   4783    29
# 793298   4089230028     4   8923    28
# 251017   2058192253     2   5819  2253
# 902234   4131680027     4  13168    27
# 928897   4160920055     4  16092    55
# 1014006  5038070014     5   3807    14
# 85502    1012531019     1   1253  1019
# 335767   3020601088     3   2060  1088
# 457203   3059530031     3   5953    31
# 856529   4112260045     4  11226    45
# 320313   3017140017     3   1714    17
# 386933   3040561003     3   4056  1003
# 851325   4110240041     4  11024    41
# 254972   3000551144     3     55  1144
# 366304   3032850018     3   3285    18
# 39102    1007931620     1    793  1620

# %%
cnt=0
for i in data['BBLE']:
    if i.isnumeric():
        cnt+=1

data['BBLE'].count()-cnt
# Out:
# 4636

# %%
data.loc[5,'BBLE'][-1]
# Out:
# '2'

# %%
for i in range(0,len(data['BBLE'])):
    if data.loc[i,'BBLE'][-1].isalpha():
        print(data.loc[i,['BBLE','BLOCK','LOT']])
# Out:
# BBLE     1000060001E
# BLOCK              6
# LOT                1
# Name: 71, dtype: object
# BBLE     1000130027E
# BLOCK             13
# LOT               27
# Name: 126, dtype: object
# BBLE     1000440001E
# BLOCK             44
# LOT                1
# Name: 6418, dtype: object
# BBLE     1000440008E
# BLOCK             44
# LOT                8
# Name: 6419, dtype: object
# BBLE     1000580001E
# BLOCK             58
# LOT                1
# Name: 7054, dtype: object
# BBLE     1000670023E
# BLOCK             67
# LOT               23
# Name: 7120, dtype: object
# BBLE     1000870001E
# BLOCK             87
# LOT                1
# Name: 8405, dtype: object
# BBLE     1000870001F
# BLOCK             87
# LOT                1
# Name: 8406, dtype: object
# BBLE     1000880001E
# BLOCK             88
# LOT                1
# Name: 8408, dtype: object
# BBLE     1000910013E
# BLOCK             91
# LOT               13
# Name: 8456, dtype: object
# BBLE     1000920001E
# ...

# %%
data.columns
# Out:
# Index(['RECORD', 'BBLE', 'BORO', 'BLOCK', 'LOT', 'EASEMENT', 'OWNER', 'BLDGCL',
#        'TAXCLASS', 'LTFRONT', 'LTDEPTH', 'EXT', 'STORIES', 'FULLVAL', 'AVLAND',
#        'AVTOT', 'EXLAND', 'EXTOT', 'EXCD1', 'STADDR', 'ZIP', 'EXMPTCL',
#        'BLDFRONT', 'BLDDEPTH', 'AVLAND2', 'AVTOT2', 'EXLAND2', 'EXTOT2',
#        'EXCD2', 'PERIOD', 'YEAR', 'VALTYPE'],
#       dtype='object')

# %%
data.count()
# Out:
# RECORD      1070994
# BBLE        1070994
# BORO        1070994
# BLOCK       1070994
# LOT         1070994
# EASEMENT       4636
# OWNER       1039249
# BLDGCL      1070994
# TAXCLASS    1070994
# LTFRONT     1070994
# LTDEPTH     1070994
# EXT          354305
# STORIES     1014730
# FULLVAL     1070994
# AVLAND      1070994
# AVTOT       1070994
# EXLAND      1070994
# EXTOT       1070994
# EXCD1        638488
# STADDR      1070318
# ZIP         1041104
# EXMPTCL       15579
# BLDFRONT    1070994
# BLDDEPTH    1070994
# AVLAND2      282726
# AVTOT2       282732
# EXLAND2       87449
# EXTOT2       130828
# EXCD2         92948
# PERIOD      1070994
# YEAR        1070994
# VALTYPE     1070994
# dtype: int64

# %% [markdown]
# ### Field Analysis

# %% [markdown]
# #### 1- Record

# %%
data.loc[:,'RECORD'].tail()   # categorical data
# Out:
# 1070989    1070990
# 1070990    1070991
# 1070991    1070992
# 1070992    1070993
# 1070993    1070994
# Name: RECORD, dtype: int64

# %%
data['RECORD']
# Out:
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
#             ...
# 1070989    1070990
# 1070990    1070991
# 1070991    1070992
# 1070992    1070993
# 1070993    1070994
# Name: RECORD, Length: 1070994, dtype: int64

# %%
data['RECORD'].value_counts()
# Out:
# 1          1
# 713987     1
# 713989     1
# 713990     1
# 713991     1
#           ..
# 357003     1
# 357004     1
# 357005     1
# 357006     1
# 1070994    1
# Name: RECORD, Length: 1070994, dtype: int64

# %%
data['RECORD'].value_counts().head(15).plot(kind='bar')
plt.xlabel('15 Record Values')
plt.ylabel('Frequency')
plt.show()

# %%
data['RECORD'].isna().sum()
# Out:
# 0

# %%
data['RECORD'].nunique()
# Out:
# 1070994

# %% [markdown]
# #### 2- BBLE

# %%
data['BBLE'].sample(20)
# Out:
# 819504     4097361028
# 460360     3060180009
# 652749     4027390032
# 589907     4006160062
# 767342     4074140032
# 878465     4120640025
# 1068044    5078670065
# 24063      1005021010
# 849440     4109710024
# 483731     3065730056
# 822792     4098820024
# 816088     4095960032
# 618685     4014070014
# 288966     3010491009
# 51372      1009151367
# 989047     5024011290
# 182421     2037480026
# 676186     4034020064
# 86911      1012701018
# 581273     4001810083
# Name: BBLE, dtype: object

# %%
data['BBLE'].isna().sum()
# Out:
# 0

# %%
data['BBLE'].nunique()
# Out:
# 1070994

# %%
data['BBLE'].value_counts()
# Out:
# 1000010101    1
# 4050107032    1
# 4050107034    1
# 4050107035    1
# 4050107036    1
#              ..
# 3027740019    1
# 3027740020    1
# 3027740021    1
# 3027740022    1
# 5080500094    1
# Name: BBLE, Length: 1070994, dtype: int64

# %%
plt.rcParams.update({'figure.figsize':(10,5)})
plt.rcParams.update({'font.size':18})

# %%
data['BBLE'].value_counts().head(15).plot(kind='bar')   
plt.ylabel('Frequency')
plt.xlabel('15 BBLE ids')
plt.show()

# %%
data['BORO'].unique()
# Out:
# array([1, 2, 3, 4, 5])

# %%
data['BORO'].value_counts()
# Out:
# 4    358046
# 3    323243
# 1    146220
# 5    136200
# 2    107285
# Name: BORO, dtype: int64

# %%
y=data['BORO'].value_counts()

# %%
data['BORO'].value_counts().plot(kind='bar')
plt.xlabel('BORO label')
plt.ylabel('Frequency')
x1,x2,y1,y2 = plt.axis()  
plt.axis((x1,x2,0,400000))
plt.show()

# %%
data['BORO'].isna().sum()
# Out:
# 0

# %%
data['BORO'].nunique()
# Out:
# 5

# %%
data['BORO'].nunique()/data['BORO'].count()*100
# Out:
# 0.00046685602346978604

# %% [markdown]
# #### Block

# %%
len(data['BLOCK'].unique())
# Out:
# 13984

# %%
data['BLOCK'].nunique()
# Out:
# 13984

# %%
data['BLOCK'].value_counts()
# Out:
# 3944     3888
# 16       3786
# 3943     3424
# 3938     2794
# 1171     2535
#          ...
# 9682        1
# 12325       1
# 10154       1
# 16129       1
# 2052        1
# Name: BLOCK, Length: 13984, dtype: int64

# %%
data['BLOCK'].value_counts().head(18).plot(kind='bar')
plt.xlabel('Block Number')
plt.ylabel('Frequency')
plt.show()

# %%
data['BLOCK'].isna().sum()
# Out:
# 0

# %%
data['BLOCK'].nunique()/data['BLOCK'].count()*100
# Out:
# 1.3057029264402975

# %% [markdown]
# #### LOT

# %%
len(data['LOT'].unique())
# Out:
# 6366

# %%
data['LOT'].value_counts()
# Out:
# 1       24367
# 20      12294
# 15      12171
# 12      12143
# 14      12074
#         ...
# 6115        1
# 6116        1
# 6117        1
# 6118        1
# 779         1
# Name: LOT, Length: 6366, dtype: int64

# %%
data['LOT'].value_counts().head(10).plot(kind='bar')
plt.xlabel('Lot number')
# Out:
# Text(0.5, 0, 'Lot number')

# %%
data.loc[:,['BBLE','BORO','BLOCK','LOT']].sample(20)
# Out:
#                BBLE  BORO  BLOCK   LOT
# 226560   2048660015     2   4866    15
# 386228   3040380112     3   4038   112
# 1003339  5032520045     5   3252    45
# 510034   3071960029     3   7196    29
# 604051   4009490022     4    949    22
# 624041   4015400021     4   1540    21
# 919967   4155470041     4  15547    41
# 865342   4116080002     4  11608     2
# 872613   4118070021     4  11807    21
# 935316   5000170027     5     17    27
# 376729   3036280008     3   3628     8
# 217235   2046100029     2   4610    29
# 939454   5001310083     5    131    83
# 503889   3070630034     3   7063    34
# 501019   3069401007     3   6940  1007
# 700519   4044920007     4   4492     7
# 657417   4028670026     4   2867    26
# 544317   3080090064     3   8009    64
# 729409   4054890044     4   5489    44
# 530186   3076920001     3   7692     1

# %%
data[data['BLOCK']==6261]
# Out:
#           RECORD        BBLE  BORO  BLOCK  LOT EASEMENT                OWNER  \
# 471188    471189  3062610001     3   6261    1      NaN  GAN ENTERPRISES LLC
# 471189    471190  3062610006     3   6261    6      NaN    GULINO GIOVANNI R
# 471190    471191  3062610007     3   6261    7      NaN       MONACO ANTONIO
# 471191    471192  3062610008     3   6261    8      NaN       MONACO ANTONIO
# 471192    471193  3062610010     3   6261   10      NaN     MONACO, ANOTONIO
# ...          ...         ...   ...    ...  ...      ...                  ...
# 1051266  1051267  5062610049     5   6261   49      NaN      ALTINI, MICHAEL
# 1051267  1051268  5062610051     5   6261   51      NaN       WILLIAM HOSMER
# 1051268  1051269  5062610054     5   6261   54      NaN     ANTHONY SELLITTI
# 1051269  1051270  5062610067     5   6261   67      NaN    CHRISTINA T GATTO
# 1051270  1051271  5062610069     5   6261   69      NaN           PAUL DADIC
#
# ...

# %%
data['LOT'].isna().sum()
# Out:
# 0

# %%
data['LOT'].nunique()/data['LOT'].count()*100
# Out:
# 0.5944010890817315

# %% [markdown]
# #### EASEMENT

# %%
data['EASEMENT'].unique()
# Out:
# array([nan, 'E', 'F', 'G', 'H', 'I', 'N', 'K', 'J', 'L', 'M', 'P', 'U'],
#       dtype=object)

# %%
data['EASEMENT'].nunique()
# Out:
# 12

# %%
data['EASEMENT'].value_counts()
# Out:
# E    4148
# F     296
# G     102
# H      33
# N      19
# I      16
# J       8
# K       5
# L       3
# P       3
# M       2
# U       1
# Name: EASEMENT, dtype: int64

# %%
data['EASEMENT'].isna().sum()
# Out:
# 1066358

# %%
data['EASEMENT'].count()/data['RECORD'].count()*100
# Out:
# 0.4328689049611856

# %%
plt.yscale('log')
data['EASEMENT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['EASEMENT'].nunique()/data['EASEMENT'].count()*100
# Out:
# 0.2588438308886971

# %%
data['OWNER'].count()/data['RECORD'].count()
# Out:
# 0.9703593110699033

# %%
data['OWNER'].value_counts()
# Out:
# PARKCHESTER PRESERVAT    6021
# PARKS AND RECREATION     4255
# DCAS                     2169
# HOUSING PRESERVATION     1904
# CITY OF NEW YORK         1450
#                          ...
# ROSE, LORNA                 1
# ELARIO ALTERNO              1
# CHARLES,VIRGINIA            1
# HAYLES, HEATHER             1
# EDWARD DONOHUE              1
# Name: OWNER, Length: 863347, dtype: int64

# %%
data['OWNER'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['OWNER'].nunique()/data['RECORD'].count()
# Out:
# 0.8061174945891387

# %%
data['RECORD'].count()
# Out:
# 1070994

# %%
data['BLDGCL']
# Out:
# 0          P7
# 1          Z9
# 2          Y7
# 3          T2
# 4          Q1
#            ..
# 1070989    A1
# 1070990    A1
# 1070991    A1
# 1070992    A1
# 1070993    A1
# Name: BLDGCL, Length: 1070994, dtype: object

# %%
data['BLDGCL'].value_counts()
# Out:
# R4    139879
# A1    123369
# A5     96984
# B1     84208
# B2     77598
#        ...
# I2         4
# I3         4
# H7         3
# E6         1
# Y5         1
# Name: BLDGCL, Length: 200, dtype: int64

# %%
data['BLDGCL'].value_counts().head(20).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data['BLDGCL'].isna().sum()
# Out:
# 0

# %%
data['BLDGCL'].nunique()
# Out:
# 200

# %%
data['BLDGCL'].nunique()/data['BLDGCL'].count()*100
# Out:
# 0.018674240938791442

# %%
data['LTFRONT']
# Out:
# 0          500
# 1           27
# 2          709
# 3          793
# 4          323
#           ...
# 1070989     60
# 1070990     62
# 1070991     53
# 1070992     52
# 1070993     50
# Name: LTFRONT, Length: 1070994, dtype: int64

# %%
data['LTFRONT'].nunique()
# Out:
# 1297

# %%
data['LTFRONT'].isnull().sum()
# Out:
# 0

# %%
data['LTFRONT'].std()
# Out:
# 74.03283871771576

# %%
data[data['LTFRONT']==0]['LTFRONT'].count()
# Out:
# 169108

# %%
data[data['LTFRONT']==0]['LTFRONT'].count()/data['LTFRONT'].count()*100
# Out:
# 15.789817683385715

# %%
data['LTFRONT'].value_counts()
# Out:
# 0       169108
# 20      135178
# 25      117306
# 40       85389
# 18       40668
#          ...
# 1320         1
# 1151         1
# 626          1
# 1162         1
# 1201         1
# Name: LTFRONT, Length: 1297, dtype: int64

# %%
data['LTFRONT'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.displot(data['LTFRONT'],kind='kde')

# %%
sns.boxplot(data['LTFRONT'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LTFRONT'>

# %%
#data.head().transpose()

# %%
xhigh=150
plt.xlim(0,150)
temp=data[data['LTFRONT']<=150]
sns.distplot(temp['LTFRONT'],bins=100,kde=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LTFRONT', ylabel='Density'>

# %%
temp[temp['LTFRONT']!=0]
# Out:
#           RECORD        BBLE  BORO  BLOCK  LOT EASEMENT  \
# 1              2  1000010201     1      1  201      NaN
# 72            73  1000070027     1      7   27      NaN
# 73            74  1000070028     1      7   28      NaN
# 74            75  1000070029     1      7   29      NaN
# 75            76  1000070030     1      7   30      NaN
# ...          ...         ...   ...    ...  ...      ...
# 1070989  1070990  5080500083     5   8050   83      NaN
# 1070990  1070991  5080500086     5   8050   86      NaN
# 1070991  1070992  5080500089     5   8050   89      NaN
# 1070992  1070993  5080500092     5   8050   92      NaN
# 1070993  1070994  5080500094     5   8050   94      NaN
#
#                          OWNER BLDGCL TAXCLASS  LTFRONT  ...  BLDFRONT  \
# 1        U S GOVT LAND & BLDGS     Z9        4       27  ...         0
# 72            NAHAS, EDMUND A.     K9        4       18  ...        19
# 73         MAYIM MGMT., L.L.C.     K9        4       19  ...        19
# ...

# %%
xhigh=150
plt.xlim(0,150)
temp=data[data['LTFRONT']<=150]
sns.distplot(temp[temp['LTFRONT']!=0]['LTFRONT'],bins=100,kde=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LTFRONT', ylabel='Density'>

# %%
data['LTDEPTH']
# Out:
# 0          1046
# 1             0
# 2           564
# 3           551
# 4          1260
#            ...
# 1070989     120
# 1070990     228
# 1070991     273
# 1070992     136
# 1070993      80
# Name: LTDEPTH, Length: 1070994, dtype: int64

# %%
data['LTDEPTH'].value_counts()
# Out:
# 100     464541
# 0       170128
# 95       31612
# 90       20294
# 80       16671
#          ...
# 1252         1
# 1567         1
# 1305         1
# 2532         1
# 1419         1
# Name: LTDEPTH, Length: 1370, dtype: int64

# %%
sns.displot(data['LTDEPTH'],kind='kde')

# %%
sns.boxplot(data['LTDEPTH'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LTDEPTH'>

# %%
xhigh=200
plt.xlim(0,200)
temp=data[data['LTDEPTH']<=200]['LTDEPTH']
sns.distplot(temp)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LTDEPTH', ylabel='Density'>

# %%
data['LTDEPTH'].isna().sum()
# Out:
# 0

# %%
data['LTDEPTH'].std()
# Out:
# 76.39628129088916

# %%
data[data['LTDEPTH']==0]['LTDEPTH'].count()
# Out:
# 170128

# %%
data[data['LTDEPTH']==0]['LTDEPTH'].count()/data['LTDEPTH'].count()
# Out:
# 0.1588505631217355

# %%
data['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
data['EXT'].isnull().sum()
# Out:
# 716689

# %%
data['EXT'].count()
# Out:
# 354305

# %%
data['EXT'].count()/data['RECORD'].count()
# Out:
# 0.33081884679092505

# %%
data['EXT'].nunique()/data['EXT'].count()*100
# Out:
# 0.000846728101494475

# %%
data['EXT'].value_counts()
# Out:
# G     266970
# E      49442
# EG     37893
# Name: EXT, dtype: int64

# %%
data['EXT'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, 'G'), Text(1, 0, 'E'), Text(2, 0, 'EG')])

# %%
data['STORIES']
# Out:
# 0          NaN
# 1          NaN
# 2          3.0
# 3          2.0
# 4          1.0
#           ...
# 1070989    2.5
# 1070990    2.5
# 1070991    2.0
# 1070992    2.0
# 1070993    2.0
# Name: STORIES, Length: 1070994, dtype: float64

# %%
data['STORIES'].nunique()
# Out:
# 111

# %%
data['FULLVAL']
# Out:
# 0           21400000.0
# 1          193800000.0
# 2          104686000.0
# 3           39200000.0
# 4          272300000.0
#               ...
# 1070989       438000.0
# 1070990       544000.0
# 1070991       480000.0
# 1070992       543000.0
# 1070993       473000.0
# Name: FULLVAL, Length: 1070994, dtype: float64

# %%
data['FULLVAL'].isnull().sum()
# Out:
# 0

# %%
sns.distplot(data['FULLVAL'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='FULLVAL', ylabel='Density'>

# %%
temp=data[data['FULLVAL']<=2000000]
plt.xlim(0,2000000)
sns.distplot(temp['FULLVAL'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='FULLVAL', ylabel='Density'>

# %%
data[data['FULLVAL']==0]['FULLVAL'].count()/data['FULLVAL'].count()*100
# Out:
# 1.2144792594543015

# %%
data['FULLVAL'].std()
# Out:
# 11582430.990666801

# %%
data['AVLAND']
# Out:
# 0            4225500.0
# 1           14310000.0
# 2           39008700.0
# 3           15255000.0
# 4          121050000.0
#               ...
# 1070989        14536.0
# 1070990         9303.0
# 1070991        14790.0
# 1070992        12388.0
# 1070993        14061.0
# Name: AVLAND, Length: 1070994, dtype: float64

# %%
data['EXCD1']
# Out:
# 0          4600.0
# 1          4600.0
# 2          2191.0
# 3          2191.0
# 4          2231.0
#             ...
# 1070989    1017.0
# 1070990    1017.0
# 1070991    1015.0
# 1070992    1017.0
# 1070993    1017.0
# Name: EXCD1, Length: 1070994, dtype: float64

# %%
sns.distplot(data['EXCD1'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EXCD1', ylabel='Density'>

# %%
data['BLDFRONT'].isnull().sum()
# Out:
# 0

# %%
data['BLDFRONT'].std()
# Out:
# 35.579696004575474

# %%
data[data['BLDFRONT']==0]['BLDFRONT'].count()/data['BLDFRONT'].count()
# Out:
# 0.21364732202047818

# %%
data['PERIOD'].nunique()
# Out:
# 1

# %%
data['PERIOD'].value_counts()
# Out:
# FINAL    1070994
# Name: PERIOD, dtype: int64

# %%
data['PERIOD'].nunique()/data['PERIOD'].count()*100
# Out:
# 9.33712046939572e-05
